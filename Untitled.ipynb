# %%
# !pip install torch==1.3.1+cu92 torchvision==0.4.2+cu92 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install torchsummary
# !pip install tensorboard networkx

# %%
run main.py
# Out:
# NODES LESS THAN 5
# Failed failedAttempts 30
# Total Attempts Swap  37
# Converting to DAG
# TOPSORT
# NODES LESS THAN 5
# NODES LESS THAN 5
# Failed failedAttempts 54
# Total Attempts Swap  76
# Converting to DAG
# TOPSORT
# NODES LESS THAN 5
# Failed failedAttempts 77
# Total Attempts Swap  125
# Converting to DAG
# TOPSORT
# /usr/local/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# torch.Size([1, 10])
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#               ReLU-1            [-1, 1, 28, 28]               0
#             Conv2d-2            [-1, 1, 28, 28]              10
#             Conv2d-3            [-1, 8, 28, 28]              16
# ...
